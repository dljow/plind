# %%
# %load_ext line_profiler
import splitedgepoints # This needs to be compiled using F2Npy
import numpy as np
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# Documentation, generated by f2py
print(splitedgepoints.split_edge_points.__doc__)
# Out:
# split_edge_points(edges,bad_edges,new_edges,new_points,n_pts,[n_edges,n_bad,n_dim])
#
# Wrapper for ``split_edge_points``.
#
# Parameters
# ----------
# edges : input rank-2 array('q') with bounds (2,n_edges)
# bad_edges : input rank-1 array('q') with bounds (n_bad)
# new_edges : in/output rank-2 array('q') with bounds (2,n_edges+n_bad)
# new_points : in/output rank-2 array('F') with bounds (n_dim,n_pts+n_bad)
# n_pts : input long
#
# Other Parameters
# ----------------
# n_edges : input long, optional
#     Default: shape(edges,1)
# n_bad : input long, optional
#     Default: len(bad_edges)
# n_dim : input long, optional
#     Default: shape(new_points,0)

# %%
edges = np.asfortranarray(np.transpose([[1, 2], [2, 3], [3,4], [4,5], [1,5]]))
points = np.asfortranarray(np.transpose([[2+2j, 1+0j, 3+0j],[1+2j, 2+0j, 3+0j],[1+1j, 7+0j, 4+0j], [1+2j, 1+0j, 4+0j], [3+2j, 3+0j, 1+0j]])) 
bad_edges=[2]
ndim=3
edges_out=np.zeros([2,6], dtype='q')
edges_out.tolist()
points_out= np.append(points, np.zeros([ndim, np.size(bad_edges)]), axis=1)
points_out.tolist()
points_out=np.asfortranarray(points_out)
print(points_out)
edges_out= np.asfortranarray(edges_out)
npts=5
# Out:
# [[2.+2.j 1.+2.j 1.+1.j 1.+2.j 3.+2.j 0.+0.j]
#  [1.+0.j 2.+0.j 7.+0.j 1.+0.j 3.+0.j 0.+0.j]
#  [3.+0.j 3.+0.j 4.+0.j 4.+0.j 1.+0.j 0.+0.j]]

# %%
# %lprun splitedgepoints.split_edge_points(edges, bad_edges, edges_out, points_out, npts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-626eb33ba9b7> in <module>
# ----> 1 get_ipython().run_line_magic('lprun', 'splitedgepoints.split_edge_points(edges, bad_edges, edges_out, points_out, npts)')
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-126> in lprun(self, parameter_s)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/lib/python3.6/site-packages/line_profiler/line_profiler.py in lprun(self, parameter_s)
#     361         try:
#     362             try:
# --> 363                 profile.runctx(arg_str, global_ns, local_ns)
#     364                 message = ''
#     365             except SystemExit:
#
# ~/.local/lib/python3.6/site-packages/line_profiler/line_profiler.py in runctx(self, cmd, globals, locals)
#     156         self.enable_by_count()
#     157         try:
# --> 158             exec_(cmd, globals, locals)
#     159         finally:
#     160             self.disable_by_count()
#
# <string> in <module>
#
# ValueError: failed to initialize intent(inout) array -- expected elsize=8 but got 16
